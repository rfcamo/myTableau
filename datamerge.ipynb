# %%
# Pandas
import pandas as pd

# %%
y2019001='JC-201901-citibike-tripdata.csv'
y2019002='JC-201902-citibike-tripdata.csv'
y2019003='JC-201903-citibike-tripdata.csv'
y2019004='JC-201904-citibike-tripdata.csv'
y2019005='JC-201905-citibike-tripdata.csv'
y2019006='JC-201906-citibike-tripdata.csv'
y201907='JC-201907-citibike-tripdata.csv'
y201908='JC-201908-citibike-tripdata.csv'
y201909='JC-201909-citibike-tripdata.csv'
y201910='JC-201910-citibike-tripdata.csv'
y201911='JC-201911-citibike-tripdata.csv'
y201912='JC-201912-citibike-tripdata.csv'
y202001='JC-202001-citibike-tripdata.csv'
y202002='JC-202002-citibike-tripdata.csv'
y202003='JC-202003-citibike-tripdata.csv'
y202004='JC-202004-citibike-tripdata.csv'
y202005='JC-202005-citibike-tripdata.csv'
y202006='JC-202006-citibike-tripdata.csv'
y202007='JC-202007-citibike-tripdata.csv'
y202008='JC-202008-citibike-tripdata.csv'
y202009='JC-202009-citibike-tripdata.csv'
y202010='JC-202010-citibike-tripdata.csv'
y202011='JC-202011-citibike-tripdata.csv'
y202012='JC-202012-citibike-tripdata.csv'

# %%
dty201901= pd.read_csv(y2019001)
dty201902= pd.read_csv(y2019002)
dty201903= pd.read_csv(y2019003)
dty201904= pd.read_csv(y2019004)
dty201905= pd.read_csv(y2019005)
dty201906= pd.read_csv(y2019006)
dty201907= pd.read_csv(y201907)
dty201908= pd.read_csv(y201908)
dty201909= pd.read_csv(y201909)
dty201910= pd.read_csv(y201910)
dty201911 = pd.read_csv(y201911)
dty201912 = pd.read_csv(y201912)
dty202001= pd.read_csv(y202001)
dty202002= pd.read_csv(y202002)
dty202003= pd.read_csv(y202003)
dty202004= pd.read_csv(y202004)
dty202005= pd.read_csv(y202005)
dty202006= pd.read_csv(y202006)
dty202007= pd.read_csv(y202007)
dty202008= pd.read_csv(y202008)
dty202009= pd.read_csv(y202009)
dty202010= pd.read_csv(y202010)
dty202011= pd.read_csv(y202011)
dty202012= pd.read_csv(y202012)

# %%
fulldata1 = dty201901.append(dty201902)
fulldata2 = fulldata1.append(dty201903)
fulldata3 = fulldata2.append(dty201904)
fulldata4 = fulldata3.append(dty201905)
fulldata5 = fulldata4.append(dty201906)
fulldata6 = fulldata5.append(dty201907)
fulldata7 = fulldata6.append(dty201908)
fulldata8 = fulldata7.append(dty201909)
fulldata9 = fulldata8.append(dty201910)
fulldata10 = fulldata9.append(dty201911)
fulldata11 = fulldata10.append(dty201912)
fulldata12 = fulldata11.append(dty202001)
fulldata13 = fulldata12.append(dty202002)
fulldata14 = fulldata13.append(dty202003)
fulldata15 = fulldata14.append(dty202004)
fulldata16 = fulldata15.append(dty202005)

fulldata17 = fulldata16.append(dty202006)
fulldata18 = fulldata17.append(dty202007)
fulldata19 = fulldata18.append(dty202008)
fulldata20 = fulldata19.append(dty202009)
fulldata21 = fulldata20.append(dty202010)
fulldata22 = fulldata21.append(dty202011)

fulldata = fulldata22.append(dty202012)
fulldata
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1               505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2               756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3              1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4              1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# ...             ...                       ...                       ...
# 11689          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 11690          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11692           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
dtable2_duplicate = fulldata[fulldata.duplicated()]
print(dtable2_duplicate)
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               156  2020-10-01 00:02:40.2600  2020-10-01 00:05:17.0140
# 1               143  2020-10-01 00:02:53.5020  2020-10-01 00:05:16.9650
# 2               305  2020-10-01 00:04:31.3160  2020-10-01 00:09:36.3840
# 3              1097  2020-10-01 00:05:18.3680  2020-10-01 00:23:36.1240
# 4               277  2020-10-01 00:09:17.5990  2020-10-01 00:13:55.5150
# ...             ...                       ...                       ...
# 13449           270  2020-10-13 15:05:35.0860  2020-10-13 15:10:05.3430
# 13452           400  2020-10-13 15:09:03.4890  2020-10-13 15:15:43.9750
# 13455           206  2020-10-13 15:11:34.3500  2020-10-13 15:15:00.5030
# 13456           216  2020-10-13 15:11:49.1510  2020-10-13 15:15:25.6930
# 13457           418  2020-10-13 15:12:31.7920  2020-10-13 15:19:30.5280
#
#        start station id start station name  start station latitude  \
# ...

# %%
fulldata.to_csv('2019-2020.csv', encoding='utf-8', index=False)
